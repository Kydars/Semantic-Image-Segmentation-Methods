# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, UpSampling2D, Conv2DTranspose, Concatenate
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 1 - Preparing dataset

# %%
pathname = 'V-01/'
sample_size = 50
original_size = (2016, 1512)
target_size = (512, 512)
learning_rate = 1e-4
num_classes = 18
batch_size = 8
epochs = 20

X_all = []
y_all = []

def one_hot_encode(masks, num_classes):
    masks_encoded = np.zeros((*masks.shape, num_classes), dtype=np.float32)
    for i in range(num_classes):
        masks_encoded[..., i] = (masks == i).astype(np.float32)
    return masks_encoded

def resize_image_and_mask(image, mask, target_size):
    image_resized = cv2.resize(image, target_size)
    mask_resized = cv2.resize(mask, target_size, interpolation=cv2.INTER_NEAREST)
    return image_resized, mask_resized

image_filenames = [img_name for img_name in os.listdir(f'{pathname}image') if ':' not in img_name]
np.random.shuffle(image_filenames)
selected_filenames = image_filenames[:sample_size]

for img_name in selected_filenames:
    img = np.asarray(cv2.imread(f'{pathname}/image/{img_name}')) / 255.0
    mask = np.asarray(cv2.imread(f'{pathname}/indexLabel/{img_name}'))
    mask = mask[:,:,0]
    
    img, mask = resize_image_and_mask(img, mask, target_size)
    X_all.append(img)
    y_all.append(mask)

X_all = np.asarray(X_all)
y_all = one_hot_encode(np.asarray(y_all), num_classes)

print(f"Shape of x_all: {X_all.shape}")
print(f"Shape of y_all: {y_all.shape}")

X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
# Out:
# Shape of x_all: (50, 512, 512, 3)
# Shape of y_all: (50, 512, 512, 18)

# %% [markdown]
# # Step 2 - Creating and compiling the model

# %%
def unet_model(shape, num_classes):
    def conv_block(inputs, filters, pool=True):
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    
        if pool == True:
            p = MaxPooling2D((2, 2))(x)
            return x, p
        else:
            return x
        
    inputs = Input(shape)

    # Encoder Layer
    x1, p1 = conv_block(inputs, 16, pool=True)
    x2, p2 = conv_block(p1, 32, pool=True)
    x3, p3 = conv_block(p2, 48, pool=True)
    x4, p4 = conv_block(p3, 64, pool=True)

    # Bridge Layer
    b1 = conv_block(p4, 128, pool=False)

    # Decoder Layer
    u1 = UpSampling2D((2, 2), interpolation="bilinear")(b1)
    c1 = Concatenate()([u1, x4])
    x5 = conv_block(c1, 64, pool=False)

    u2 = UpSampling2D((2, 2), interpolation="bilinear")(x5)
    c2 = Concatenate()([u2, x3])
    x6 = conv_block(c2, 48, pool=False)
    
    u3 = UpSampling2D((2, 2), interpolation="bilinear")(x6)
    c3 = Concatenate()([u3, x2])
    x7 = conv_block(c3, 32, pool=False)
    
    u4 = UpSampling2D((2, 2), interpolation="bilinear")(x7)
    c4 = Concatenate()([u4, x1])
    x8 = conv_block(c4, 16, pool=False)

    # Output layer
    output = Conv2D(num_classes, 1, padding="same", activation="softmax")(x8)
    return Model(inputs, output)

model = unet_model((512, 512, 3), num_classes)
print(model.summary())

model.compile(loss="categorical_crossentropy",
              optimizer=Adam(learning_rate),
              metrics=[MeanIoU(num_classes=18)])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 16  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 256, 256, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32  0          ['activation_3[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 48  13872       ['max_pooling2d_1[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 48  192        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 128, 128, 48  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 48)  0           ['activation_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   27712       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 64)  0           ['activation_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 128)  0           ['activation_9[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 192)  0           ['up_sampling2d[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 64  0          ['activation_11[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 11  0           ['up_sampling2d_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 48  48432       ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 48  192        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 128, 128, 48  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 48  0          ['activation_13[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 80  0           ['up_sampling2d_2[0][0]',
#                                 )                                 'activation_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 32  23072       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 32  0          ['activation_15[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 48  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 16  6928        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 16  64         ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 16  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 18  306         ['activation_17[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 311,714
# Trainable params: 310,818
# Non-trainable params: 896
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Step 3 - Training the model

# %%
print(y_train.shape)

model_file="models/UNet_model.h5"

callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-6),
    EarlyStopping(monitor="val_loss", patience=5, verbose=1)
]

history = model.fit(X_train, y_train, 
          validation_data=(X_val, y_val),
          batch_size=batch_size, 
          epochs=epochs,
          steps_per_epoch = np.ceil(len(X_train) / batch_size),
          verbose=1,
          validation_steps = np.ceil(len(X_val) / batch_size),
          shuffle=True,
          callbacks=callbacks)
# Out:
# (32, 512, 512, 18)
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 2.4126 - mean_io_u: 0.4526
# Epoch 1: val_loss improved from inf to 2.55599, saving model to models\UNet_model.h5
# 4/4 [==============================] - 39s 9s/step - loss: 2.4126 - mean_io_u: 0.4526 - val_loss: 2.5560 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 2.1958 - mean_io_u: 0.4526
# Epoch 2: val_loss improved from 2.55599 to 2.54546, saving model to models\UNet_model.h5
# 4/4 [==============================] - 35s 9s/step - loss: 2.1958 - mean_io_u: 0.4526 - val_loss: 2.5455 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 2.0388 - mean_io_u: 0.4526
# Epoch 3: val_loss improved from 2.54546 to 2.53884, saving model to models\UNet_model.h5
# 4/4 [==============================] - 39s 11s/step - loss: 2.0388 - mean_io_u: 0.4526 - val_loss: 2.5388 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 1.9281 - mean_io_u: 0.4526
# Epoch 4: val_loss improved from 2.53884 to 2.53217, saving model to models\UNet_model.h5
# 4/4 [==============================] - 38s 10s/step - loss: 1.9281 - mean_io_u: 0.4526 - val_loss: 2.5322 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 1.8617 - mean_io_u: 0.4526
# Epoch 5: val_loss improved from 2.53217 to 2.52465, saving model to models\UNet_model.h5
# 4/4 [==============================] - 38s 10s/step - loss: 1.8617 - mean_io_u: 0.4526 - val_loss: 2.5247 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 1.7882 - mean_io_u: 0.4526
# Epoch 6: val_loss improved from 2.52465 to 2.51967, saving model to models\UNet_model.h5
# 4/4 [==============================] - 37s 10s/step - loss: 1.7882 - mean_io_u: 0.4526 - val_loss: 2.5197 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 1.7671 - mean_io_u: 0.4526
# Epoch 7: val_loss improved from 2.51967 to 2.51744, saving model to models\UNet_model.h5
# 4/4 [==============================] - 36s 9s/step - loss: 1.7671 - mean_io_u: 0.4526 - val_loss: 2.5174 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 1.7201 - mean_io_u: 0.4526
# Epoch 8: val_loss improved from 2.51744 to 2.51543, saving model to models\UNet_model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 1.7201 - mean_io_u: 0.4526 - val_loss: 2.5154 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 1.6775 - mean_io_u: 0.4526
# Epoch 9: val_loss improved from 2.51543 to 2.51351, saving model to models\UNet_model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 1.6775 - mean_io_u: 0.4526 - val_loss: 2.5135 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 1.6608 - mean_io_u: 0.4526
# Epoch 10: val_loss improved from 2.51351 to 2.51166, saving model to models\UNet_model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 1.6608 - mean_io_u: 0.4526 - val_loss: 2.5117 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 1.6324 - mean_io_u: 0.4526
# Epoch 11: val_loss improved from 2.51166 to 2.50983, saving model to models\UNet_model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 1.6324 - mean_io_u: 0.4526 - val_loss: 2.5098 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 1.6074 - mean_io_u: 0.4526
# Epoch 12: val_loss improved from 2.50983 to 2.50764, saving model to models\UNet_model.h5
# 4/4 [==============================] - 35s 9s/step - loss: 1.6074 - mean_io_u: 0.4526 - val_loss: 2.5076 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5951 - mean_io_u: 0.4526
# Epoch 13: val_loss improved from 2.50764 to 2.50579, saving model to models\UNet_model.h5
# 4/4 [==============================] - 34s 9s/step - loss: 1.5951 - mean_io_u: 0.4526 - val_loss: 2.5058 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5659 - mean_io_u: 0.4526
# Epoch 14: val_loss improved from 2.50579 to 2.50436, saving model to models\UNet_model.h5
# 4/4 [==============================] - 35s 9s/step - loss: 1.5659 - mean_io_u: 0.4526 - val_loss: 2.5044 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5510 - mean_io_u: 0.4526
# Epoch 15: val_loss improved from 2.50436 to 2.50409, saving model to models\UNet_model.h5
# 4/4 [==============================] - 35s 9s/step - loss: 1.5510 - mean_io_u: 0.4526 - val_loss: 2.5041 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5298 - mean_io_u: 0.4526
# Epoch 16: val_loss did not improve from 2.50409
# 4/4 [==============================] - 34s 9s/step - loss: 1.5298 - mean_io_u: 0.4526 - val_loss: 2.5043 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5191 - mean_io_u: 0.4526
# Epoch 17: val_loss did not improve from 2.50409
# 4/4 [==============================] - 35s 9s/step - loss: 1.5191 - mean_io_u: 0.4526 - val_loss: 2.5062 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5169 - mean_io_u: 0.4526
# Epoch 18: val_loss did not improve from 2.50409
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 4/4 [==============================] - 34s 9s/step - loss: 1.5169 - mean_io_u: 0.4526 - val_loss: 2.5084 - val_mean_io_u: 0.4510 - lr: 1.0000e-04
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5072 - mean_io_u: 0.4526
# Epoch 19: val_loss did not improve from 2.50409
# 4/4 [==============================] - 33s 9s/step - loss: 1.5072 - mean_io_u: 0.4526 - val_loss: 2.5102 - val_mean_io_u: 0.4510 - lr: 1.0000e-05
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 1.4873 - mean_io_u: 0.4526
# Epoch 20: val_loss did not improve from 2.50409
# 4/4 [==============================] - 33s 9s/step - loss: 1.4873 - mean_io_u: 0.4526 - val_loss: 2.5119 - val_mean_io_u: 0.4510 - lr: 1.0000e-05
# Epoch 20: early stopping

# %% [markdown]
# # Step 4 - Predicting using the trained model

# %%
img = cv2.imread('V-01/image/1623377792-158486120.png') / 255.0
img_resized = cv2.resize(img, target_size)

colours = [[0, 0, 0], 
           [75, 25, 230], 
           [75, 180, 60], 
           [25, 225, 255], 
           [200, 130, 0], 
           [180, 30, 145], 
           [240, 240, 70], 
           [230, 50, 240], 
           [60, 245, 210], 
           [75, 25, 230], 
           [128, 128, 0], 
           [40, 110, 170], 
           [200, 250, 255], 
           [0, 0, 128], 
           [195, 255, 170], 
           [0, 128, 128], 
           [190, 190, 250], 
           [128, 0, 0], 
           [128, 128, 128]]

y_pred = model.predict(np.expand_dims(img_resized, axis=0))
y_pred_labels = np.argmax(y_pred, axis=-1)[0]
print(y_pred_labels)
y_pred_resized = cv2.resize(y_pred_labels, original_size, interpolation=cv2.INTER_NEAREST)
print(np.unique(y_pred_resized))
result = np.array([[colours[num] for num in row] for row in y_pred_resized])
original = np.asarray(cv2.imread('V-01/image/1623377792-158486120.png'))
actual = np.asarray(cv2.imread('V-01/label/1623377792-158486120.png'))

def display_single_prediction(original, actual, predicted):
    
    plt.figure(figsize=(10, 5))

    # Original image
    plt.subplot(1, 3, 1)
    plt.title("Original Image")
    plt.imshow(cv2.cvtColor(original, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    
    # Original image
    plt.subplot(1, 3, 2)
    plt.imshow(cv2.cvtColor(actual, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    
    # Predicted mask
    plt.subplot(1, 3, 3)
    plt.imshow(predicted, cmap='jet', vmin=0, vmax=num_classes-1)
    plt.axis('off')
    
    plt.show()

# Display predictions for the single test image
display_single_prediction(original, actual, y_pred_resized)
# Out:
# 1/1 [==============================] - 0s 226ms/step
# [[ 8  8  0 ...  1  8  8]
#  [ 8 10 17 ...  0  0  0]
#  [ 8 10 17 ...  2 15  0]
#  ...
#  [ 8  2  2 ...  2  2  0]
#  [15  2  2 ...  2 15  0]
#  [ 8  8  0 ...  8  8  0]]
# [ 0  1  2  3  4  5  8  9 10 11 14 15 17]
