# %%
import os
import numpy as np
import cv2
import tensorflow as tf
import keras
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow import io as tf_io
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPool2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, Concatenate
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 1 - Preparing dataset

# %%
import random

def get_input_output_paths(root_dir, sub_dirs, max_samples=None):
    input_img_paths = []
    target_img_paths = []
    samples_per_dir = max_samples // len(sub_dirs) if max_samples else None
    for sub_dir in sub_dirs:
        input_dir = os.path.join(root_dir, sub_dir, 'image')
        sub_input_img_paths = [os.path.join(input_dir, f) for f in os.listdir(input_dir)]
        random.shuffle(sub_input_img_paths)
        sub_target_img_paths = list(map(lambda x: x.replace("image", "indexLabel"), sub_input_img_paths))
        
        if samples_per_dir:
            sub_input_img_paths = sub_input_img_paths[:samples_per_dir]
            sub_target_img_paths = sub_target_img_paths[:samples_per_dir]
        
        input_img_paths.extend(sub_input_img_paths)
        target_img_paths.extend(sub_target_img_paths)
    return input_img_paths, target_img_paths

input_img_paths, target_img_paths = get_input_output_paths('WildScenes2d', ['V-01', 'V-02', 'V-03'], 1000)

# print(input_img_paths)
# print(target_img_paths)

# %%
import random

input_dir = "V-01/image/"
target_dir = "V-01/indexLabel"
img_size = (256, 256)
num_classes = 19
batch_size = 16
input_size = 20



def get_input_output_paths_old():
    input_img_paths = [
            os.path.join(input_dir, fname)
            for fname in os.listdir(input_dir)
            if fname.endswith(".png")
        ]

    random.shuffle(input_img_paths)

    target_img_paths = list(map(lambda x: x.replace("image", "indexLabel"), input_img_paths))

    input_img_paths = input_img_paths[:input_size]
    target_img_paths = target_img_paths[:input_size]
    

    return input_img_paths, target_img_paths

# comment out the following after the complete dataset is downloaded in WildScenes2d and
# replace with the commented function call in the cell above
# input_img_paths, target_img_paths = get_input_output_paths_old()

print("Number of samples:", len(input_img_paths))
# Out:
# Number of samples: 999

# %%
def load_mask(img_path):
    target_img = tf_io.read_file(img_path)
    target_img = tf_io.decode_png(target_img, channels=1)
    target_img = tf_image.convert_image_dtype(target_img, "uint8")
    
    return target_img

def load_image(img_path):
    input_img = tf_io.read_file(img_path)
    input_img = tf_io.decode_png(input_img, channels=3)
    input_img = tf_image.resize(input_img, img_size)
    input_img = tf_image.convert_image_dtype(input_img, "float32")
    
    return input_img

def get_dataset(
    batch_size,
    img_size,
    input_img_paths,
    target_img_paths,
    max_dataset_len=None,
):
    """Returns a TF Dataset."""

    def load_img_masks(input_img_path, target_img_path):
        input_img = tf_io.read_file(input_img_path)
        input_img = tf_io.decode_png(input_img, channels=3)
        input_img = tf_image.resize(input_img, img_size)
        input_img = tf_image.convert_image_dtype(input_img, "float32")

        target_img = tf_io.read_file(target_img_path)
        target_img = tf_io.decode_png(target_img, channels=1)
        target_img = tf_image.resize(target_img, img_size, method="nearest")
        target_img = tf_image.convert_image_dtype(target_img, "uint8")
        
        target_one_hot = tf.one_hot(tf.squeeze(target_img), num_classes)
    
        return input_img, target_one_hot

    # limit the size of data
    if max_dataset_len:
        input_img_paths = input_img_paths[:max_dataset_len]
        target_img_paths = target_img_paths[:max_dataset_len]
        
    dataset = tf_data.Dataset.from_tensor_slices((input_img_paths, target_img_paths))
    dataset = dataset.map(load_img_masks, num_parallel_calls=tf_data.AUTOTUNE)
    return dataset.batch(batch_size)

# %%
from sklearn.model_selection import train_test_split

def get_majority_values(filepath):
    arr = np.array(load_mask(filepath))
    flat_arr = arr.flatten()
    
    # Get unique values and their counts
    unique, counts = np.unique(flat_arr, return_counts=True)
    
    # Find the maximum count
    max_count = counts.max()
    
    # Get all values with the maximum count
    majority_values = unique[counts == max_count]
    
    return majority_values[0]

def get_dataset_majority_values(dataset):
    return np.array(list(map(get_majority_values, dataset)))

def train_val_test_split(X_all, y_all, test_size=0.2, validation_size=0.2):
    X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=test_size, stratify=get_dataset_majority_values(y_all), random_state=42)
    X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train, test_size=validation_size/(1-test_size), stratify=get_dataset_majority_values(y_train), random_state=42)
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = train_val_test_split(input_img_paths, target_img_paths)

print("Classes in the dataset:", get_dataset_majority_values(target_img_paths))
print("Number of train samples:", len(X_train))
print("Number of validation samples:", len(X_val))
print("Number of test samples:", len(X_test))

train_dataset = get_dataset(
    batch_size,
    img_size,
    X_train,
    y_train,
)

valid_dataset = get_dataset(
    batch_size,
    img_size,
    X_val,
    y_val,
)
# Out:
# Classes in the dataset: [ 8  8  8  8  8  8  8  8  8  8  8  8  8  8 17  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 17  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8 17  8  8  8  2  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8 17  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8 17  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8 17  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8 17  8  8  8 17  8  8  8 17  8  8  8  8  8  8  8 17  8
#   8 17  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8 17  7  8 17 17  8  8  8  8  8  8  8  8  2  8  8
#   8  8 18  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 17  8  8  8  8  8
#   8  8  8  8  8  8 17  8  8  8  8 17  8  8  8  8  8 17  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8 17  8  8  8  8  8  8  8  8  8  8  8  8  8  8  7  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 17  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8 18  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 18 17  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8 17  8  8  8  8  8  8  8  8 17  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 17  8  8  8  8  8  8
#   8  8  8  8  8  8 17  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8 18  8
#   8  8 18  8  8  8  8  8  8  8  2  8  8  8  8  8  8  8 18  8  8  2  2  8
#   8  8  8  8  8  8  8 18  8  8  2  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  2
#   8  8  8  8  7  8  8  8  7  8  8  8 18  8  2  8  8  2  8  8  8  8  8  2
#   8  8  8  8  8  8  8  8  8 18  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  2  8  8  8  8  8  8  8  7  8  8  8  2  8  8  8 18  8  8
#   8  8  8  8  8  8  8  2 18  8  8 18  8  8  8  8  8  8  8  8  8  8  8  8
#   2  2  8  8  8  2  8  8  8  8  8  8 18  2  8  8  8  8  8  8  2  8  8  2
#   8  8  8  8  8  8  8  8  8  8  8  8  8  2  8  2  8  8  8  8  8  8  8  8
#  18  8  8  8  8  8  8  8  8  8  7  8  8  8  8  2  8  8  8  8  8  8  8  8
#   8  8  8  8 18  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  2  8  8
#   8  2  8  8  8  8  8  2  8  8  8  8  8  8  8  8 18  8 18  8  8  8  8  8
#   8  8 18  8  8  8  8  2 18  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  2  8  8  8  8 18  8  8  8  8  8]
# Number of train samples: 599
# Number of validation samples: 200
# Number of test samples: 200

# %%
def build_unet(shape, num_classes):
    def conv_block(inputs, filters, pool=True):
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    
        if pool == True:
            p = MaxPooling2D((2, 2))(x)
            return x, p
        else:
            return x
        
    inputs = Input(shape)

    # Encoder Layer
    x1, p1 = conv_block(inputs, 16, pool=True)
    x2, p2 = conv_block(p1, 32, pool=True)
    x3, p3 = conv_block(p2, 48, pool=True)
    x4, p4 = conv_block(p3, 64, pool=True)

    # Bridge Layer
    b1 = conv_block(p4, 128, pool=False)

    # Decoder Layer
    u1 = UpSampling2D((2, 2), interpolation="bilinear")(b1)
    c1 = Concatenate()([u1, x4])
    x5 = conv_block(c1, 64, pool=False)

    u2 = UpSampling2D((2, 2), interpolation="bilinear")(x5)
    c2 = Concatenate()([u2, x3])
    x6 = conv_block(c2, 48, pool=False)
    
    u3 = UpSampling2D((2, 2), interpolation="bilinear")(x6)
    c3 = Concatenate()([u3, x2])
    x7 = conv_block(c3, 32, pool=False)
    
    u4 = UpSampling2D((2, 2), interpolation="bilinear")(x7)
    c4 = Concatenate()([u4, x1])
    x8 = conv_block(c4, 16, pool=False)

    # Output layer
    output = Conv2D(num_classes, 1, padding="same", activation="softmax")(x8)
    return Model(inputs, output)

# def conv_block(input, num_filters):
#     x = Conv2D(num_filters, 3, padding="same")(input)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)

#     x = Conv2D(num_filters, 3, padding="same")(x)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)

#     return x

# def encoder_block(input, num_filters):
#     x = conv_block(input, num_filters)
#     p = MaxPool2D((2, 2))(x)
#     return x, p

# def decoder_block(input, skip_features, num_filters):
#     x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
#     x = Concatenate()([x, skip_features])
#     x = conv_block(x, num_filters)
#     return x

# def build_unet(input_shape, num_classes):
#     inputs = Input(input_shape)

#     s1, p1 = encoder_block(inputs, 64)
#     s2, p2 = encoder_block(p1, 128)
#     s3, p3 = encoder_block(p2, 256)
#     s4, p4 = encoder_block(p3, 512)

#     b1 = conv_block(p4, 1024)

#     d1 = decoder_block(b1, s4, 512)
#     d2 = decoder_block(d1, s3, 256)
#     d3 = decoder_block(d2, s2, 128)
#     d4 = decoder_block(d3, s1, 64)

#     outputs = Conv2D(num_classes, 1, padding="same", activation="softmax")(d4)

#     model = Model(inputs, outputs, name="U-Net")
#     return model

# model = unet_model((256, 256, 3), num_classes)
model = build_unet((256, 256, 3), num_classes)
print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     13,872 │ max_pooling2d_1[… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │     27,712 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │     73,856 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ activation_9[0][… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 192)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    110,656 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ activation_11[0]… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 112)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │     48,432 │ concatenate_1[0]… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ activation_13[0]… │
# │ (UpSampling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 80)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     23,072 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ activation_15[0]… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        323 │ activation_17[0]… │
# │                     │ 19)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 311,731 (1.19 MB)
#  Trainable params: 310,835 (1.19 MB)
#  Non-trainable params: 896 (3.50 KB)
# None

# %%
@tf.keras.utils.register_keras_serializable()
class CustomMeanIoU(MeanIoU):
    def __init__(self, num_classes=None, name=None, dtype=None, **kwargs):
        super(CustomMeanIoU, self).__init__(num_classes=num_classes, name=name, dtype=dtype, **kwargs)

    @tf.function(reduce_retracing=True)
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.math.argmax(y_true, axis=-1)
        y_pred = tf.math.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

    def get_config(self):
        config = super(CustomMeanIoU, self).get_config()
        config.update({
            "num_classes": self.num_classes,
            "name": self.name,
            "dtype": self.dtype,
        })
        return config

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=[MeanIoU(num_classes=num_classes)])

callbacks = [
    ModelCheckpoint("models/unet_final_checkpoint.keras", save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-6),
    EarlyStopping(monitor="val_loss", patience=5, verbose=1),
]

epochs = 200

model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=valid_dataset,
    callbacks=callbacks,
    shuffle=True,
    verbose=1,
)

model.save('models/unet_final_model.keras')
# Out:
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 164s 3s/step - loss: 2.5912 - mean_io_u: 0.4706 - val_loss: 2.6541 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - loss: 2.1317 - mean_io_u: 0.4706 - val_loss: 2.6142 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - loss: 1.9442 - mean_io_u: 0.4706 - val_loss: 2.5005 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 116s 3s/step - loss: 1.8290 - mean_io_u: 0.4706 - val_loss: 2.3217 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 109s 3s/step - loss: 1.7523 - mean_io_u: 0.4706 - val_loss: 2.1323 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - loss: 1.6904 - mean_io_u: 0.4706 - val_loss: 1.9727 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 111s 3s/step - loss: 1.6342 - mean_io_u: 0.4706 - val_loss: 1.8483 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 1.5827 - mean_io_u: 0.4706 - val_loss: 1.7470 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - loss: 1.5343 - mean_io_u: 0.4706 - val_loss: 1.6655 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - loss: 1.4881 - mean_io_u: 0.4706 - val_loss: 1.5972 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 111s 3s/step - loss: 1.4437 - mean_io_u: 0.4706 - val_loss: 1.5350 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 110s 3s/step - loss: 1.4008 - mean_io_u: 0.4706 - val_loss: 1.4814 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 111s 3s/step - loss: 1.3594 - mean_io_u: 0.4706 - val_loss: 1.4353 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 114s 3s/step - loss: 1.3194 - mean_io_u: 0.4706 - val_loss: 1.3949 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 111s 3s/step - loss: 1.2810 - mean_io_u: 0.4706 - val_loss: 1.3556 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 16/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 114s 3s/step - loss: 1.2438 - mean_io_u: 0.4706 - val_loss: 1.3210 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 17/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 139s 3s/step - loss: 1.2079 - mean_io_u: 0.4706 - val_loss: 1.2841 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 18/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 113s 3s/step - loss: 1.1733 - mean_io_u: 0.4706 - val_loss: 1.2502 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 19/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 111s 3s/step - loss: 1.1397 - mean_io_u: 0.4706 - val_loss: 1.2153 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 20/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 115s 3s/step - loss: 1.1072 - mean_io_u: 0.4706 - val_loss: 1.1811 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 21/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 116s 3s/step - loss: 1.0758 - mean_io_u: 0.4706 - val_loss: 1.1447 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 22/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 117s 3s/step - loss: 1.0455 - mean_io_u: 0.4706 - val_loss: 1.1087 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 23/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 115s 3s/step - loss: 1.0161 - mean_io_u: 0.4706 - val_loss: 1.0750 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 24/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 113s 3s/step - loss: 0.9879 - mean_io_u: 0.4706 - val_loss: 1.0431 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 25/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 113s 3s/step - loss: 0.9608 - mean_io_u: 0.4706 - val_loss: 1.0133 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 26/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - loss: 0.9348 - mean_io_u: 0.4706 - val_loss: 0.9860 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 27/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 115s 3s/step - loss: 0.9100 - mean_io_u: 0.4706 - val_loss: 0.9600 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 28/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 113s 3s/step - loss: 0.8862 - mean_io_u: 0.4706 - val_loss: 0.9354 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 29/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - loss: 0.8634 - mean_io_u: 0.4706 - val_loss: 0.9132 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 30/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - loss: 0.8417 - mean_io_u: 0.4706 - val_loss: 0.8921 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 31/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - loss: 0.8208 - mean_io_u: 0.4706 - val_loss: 0.8721 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 32/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 124s 3s/step - loss: 0.8009 - mean_io_u: 0.4706 - val_loss: 0.8533 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 33/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - loss: 0.7819 - mean_io_u: 0.4706 - val_loss: 0.8350 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 34/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - loss: 0.7637 - mean_io_u: 0.4706 - val_loss: 0.8185 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 35/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 124s 3s/step - loss: 0.7464 - mean_io_u: 0.4706 - val_loss: 0.8030 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 36/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 115s 3s/step - loss: 0.7298 - mean_io_u: 0.4706 - val_loss: 0.7885 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 37/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 118s 3s/step - loss: 0.7141 - mean_io_u: 0.4706 - val_loss: 0.7744 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 38/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - loss: 0.6989 - mean_io_u: 0.4706 - val_loss: 0.7609 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 39/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.6845 - mean_io_u: 0.4706 - val_loss: 0.7492 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 40/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.6708 - mean_io_u: 0.4706 - val_loss: 0.7380 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 41/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.6577 - mean_io_u: 0.4706 - val_loss: 0.7276 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 42/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - loss: 0.6452 - mean_io_u: 0.4706 - val_loss: 0.7172 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 43/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - loss: 0.6332 - mean_io_u: 0.4706 - val_loss: 0.7076 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 44/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - loss: 0.6217 - mean_io_u: 0.4706 - val_loss: 0.6983 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 45/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - loss: 0.6108 - mean_io_u: 0.4706 - val_loss: 0.6900 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 46/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - loss: 0.6003 - mean_io_u: 0.4706 - val_loss: 0.6822 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-04
# Epoch 47/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - loss: 0.5902 - mean_io_u: 0.4706 - val_loss: 0.6754 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e
- val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 175/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3966 - mean_io_u: 0.4706 - val_loss: 0.5563 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 176/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.3960 - mean_io_u: 0.4706 - val_loss: 0.5562 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 177/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3954 - mean_io_u: 0.4706 - val_loss: 0.5561 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 178/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3949 - mean_io_u: 0.4706 - val_loss: 0.5559 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 179/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3943 - mean_io_u: 0.4706 - val_loss: 0.5558 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 180/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 107s 3s/step - loss: 0.3938 - mean_io_u: 0.4706 - val_loss: 0.5557 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 181/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.3932 - mean_io_u: 0.4706 - val_loss: 0.5555 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 182/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3927 - mean_io_u: 0.4706 - val_loss: 0.5554 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 183/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3922 - mean_io_u: 0.4706 - val_loss: 0.5552 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 184/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.3916 - mean_io_u: 0.4706 - val_loss: 0.5551 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 185/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - loss: 0.3911 - mean_io_u: 0.4706 - val_loss: 0.5549 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 186/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.3906 - mean_io_u: 0.4706 - val_loss: 0.5548 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 187/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.3900 - mean_io_u: 0.4706 - val_loss: 0.5547 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 188/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 107s 3s/step - loss: 0.3895 - mean_io_u: 0.4706 - val_loss: 0.5546 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 189/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - loss: 0.3890 - mean_io_u: 0.4706 - val_loss: 0.5544 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 190/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.3884 - mean_io_u: 0.4706 - val_loss: 0.5543 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 191/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - loss: 0.3879 - mean_io_u: 0.4706 - val_loss: 0.5542 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 192/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3874 - mean_io_u: 0.4706 - val_loss: 0.5541 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 193/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 107s 3s/step - loss: 0.3868 - mean_io_u: 0.4706 - val_loss: 0.5540 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 194/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3863 - mean_io_u: 0.4706 - val_loss: 0.5539 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 195/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3858 - mean_io_u: 0.4706 - val_loss: 0.5538 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 196/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3853 - mean_io_u: 0.4706 - val_loss: 0.5537 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 197/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 109s 3s/step - loss: 0.3848 - mean_io_u: 0.4706 - val_loss: 0.5536 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 198/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step - loss: 0.3842 - mean_io_u: 0.4706 - val_loss: 0.5535 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 199/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 149s 3s/step - loss: 0.3837 - mean_io_u: 0.4706 - val_loss: 0.5534 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05
# Epoch 200/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - loss: 0.3832 - mean_io_u: 0.4706 - val_loss: 0.5533 - val_mean_io_u: 0.4707 - learning_rate: 1.0000e-05

# %%
model = tf.keras.models.load_model('models/unet_final_model.keras')

# %%
from sklearn.metrics import jaccard_score, accuracy_score, f1_score

y_pred = model.predict(get_dataset(batch_size, img_size, X_test, y_test))
y_pred_whole = np.argmax(y_pred, axis=-1).flatten()

y_test_imgs = [load_mask(x) for x in y_test]
y_test_whole = np.array([tf_image.resize(x, (256, 256)) for x in y_test_imgs])
y_test_whole = y_test_whole.flatten().astype(int)

print(len(y_pred_whole))
print(len(y_test_whole))

iou = jaccard_score(y_test_whole, y_pred_whole, average=None)
print(f'IoU for each class: {iou}')
print(f'Mean IoU: {np.mean([x for x in iou if x > 0.01])}')
print(f'Accuracy: {accuracy_score(y_test_whole, y_pred_whole)}')
f1 = f1_score(y_test_whole, y_pred_whole, labels=[x for x in range(19)], average=None)
print(f'F1: {f1}')
print(f'Mean F1: {np.mean([x for x in f1 if x > 0.01])}')
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step
# 13107200
# 13107200
# IoU for each class: [0.77439955 0.         0.         0.         0.         0.43887632
#  0.80484852 0.14812544 0.         0.         0.         0.
#  0.         0.         0.         0.8127063  0.63349442]
# Mean IoU: 0.6020750928429215
# Accuracy: 0.8261184692382812
# F1: [0.         0.         0.87285815 0.         0.         0.
#  0.         0.61002647 0.89187376 0.25803007 0.         0.
#  0.         0.         0.         0.         0.         0.8966773
#  0.77563095]
# Mean F1: 0.7175161183666644
# c:\Users\kylew\Dev\9517\ass1\Semantic-Image-Segmentation-Techniques\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(y_pred_whole.shape)
print(y_test_whole.shape)
print(y_pred_whole)
print(y_test_whole)
# Out:
# (13107200,)
# (13107200,)
# [ 8  8  8 ... 18 18 18]
# [ 8  8  8 ... 18 18 18]

# %%
colours = [[0, 0, 0], 
           [75, 25, 230], 
           [75, 180, 60], 
           [25, 225, 255], 
           [200, 130, 0], 
           [180, 30, 145], 
           [240, 240, 70], 
           [230, 50, 240], 
           [60, 245, 210], 
           [75, 25, 230], 
           [128, 128, 0], 
           [40, 110, 170], 
           [200, 250, 255], 
           [0, 0, 128], 
           [195, 255, 170], 
           [0, 128, 128], 
           [190, 190, 250], 
           [128, 0, 0], 
           [128, 128, 128]]

# test_sample = "1623378124-681919295.png"
test_sample = "1623377812-526645347.png"
original_size = (2016, 1512)

test_img = load_image("WildScenes2d/V-01/image/" + test_sample)
y_pred = model.predict(np.expand_dims(test_img, axis=0))
y_pred_labels = np.argmax(y_pred, axis=-1)[0]
y_pred_resized = cv2.resize(y_pred_labels, original_size, interpolation=cv2.INTER_NEAREST)
predicted_img = np.array([[colours[num] for num in row] for row in y_pred_resized])
print(y_pred_labels)


truth_labels = load_mask("WildScenes2d/V-01/indexLabel/" + test_sample)
truth_img = np.array([[colours[num] for num in row] for row in np.array(truth_labels).reshape(1512, 2016)])
truth_img = cv2.resize(truth_img, original_size, interpolation=cv2.INTER_NEAREST)

import matplotlib.pyplot as plt

# Create a figure with 1 row and 3 columns of subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the original image on the first subplot
axes[0].imshow(cv2.imread("WildScenes2d/V-01/image/" + test_sample))
axes[0].set_title('Original')
axes[0].axis('off')  # Hide axes

# Plot the predicted image on the second subplot
axes[1].imshow(predicted_img)
axes[1].set_title('Predicted')
axes[1].axis('off')  # Hide axes

# Plot the truth image on the third subplot
axes[2].imshow(truth_img)
axes[2].set_title('Truth')
axes[2].axis('off')  # Hide axes
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# [[ 8  8  8 ...  8  8  8]
#  [ 8  8  8 ...  8  8  8]
#  [ 8  8  8 ...  8  8  8]
#  ...
#  [18 18 18 ...  8  8  8]
#  [18 18 18 ...  8  8 18]
#  [18 18 18 ... 18 18  8]]
# (-0.5, 2015.5, 1511.5, -0.5)
